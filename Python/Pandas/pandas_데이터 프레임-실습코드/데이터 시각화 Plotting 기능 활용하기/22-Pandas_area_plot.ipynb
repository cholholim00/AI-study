# %% [markdown]
# ## area plot 산점도
#
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.430494  0.857406  0.547336  0.929569
# 1  0.015681  0.576150  0.020354  0.995982
# 2  0.553457  0.680463  0.470884  0.474952
# 3  0.722488  0.049663  0.785792  0.494001
# 4  0.291848  0.355209  0.150714  0.043932

# %%
df.plot(grid=True)

# %%
df.plot.area(grid=True)

# %%
df.plot.area(stacked=False, grid=True)
